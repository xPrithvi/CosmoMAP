# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 # Free memory before training
#       4 gc.collect()
# ----> 5 tf.keras.backend.clear_session()
#
# NameError: name 'tf' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import gc

# Load and immediately process one array at a time
def safe_log_normalize(data, epsilon=1e-6):
    min_val = np.min(data)
    max_val = np.max(data)
    normalized = np.log1p(data - min_val + epsilon) / np.log1p(max_val - min_val + epsilon)
    return normalized

# Step 1: Load, normalize, and display X_mass, then convert to final array
print("Processing dark matter mass...")
X_mass = np.load(r"/home/amanbh/projects/tf217/DISS/Maps_Mcdm_IllustrisTNG_LH_z=0.00.npy")
print(f"X_mass shape: {X_mass.shape}")
print(f"Dark Matter Mass min-max: {X_mass.min()} - {X_mass.max()}")

# Normalize in smaller batches
batch_size = 10
X_mass = X_mass.astype(np.float32)  # Convert to float32 to save memory
X_mass_norm = np.zeros_like(X_mass, dtype=np.float32)

for i in range(0, len(X_mass), batch_size):
    X_mass_norm[i:i+batch_size] = safe_log_normalize(X_mass[i:i+batch_size])

# Display one sample
plt.figure(figsize=(5, 5))
plt.imshow(X_mass_norm[0], cmap="inferno")
plt.title("Normalized Dark Matter Mass")
plt.colorbar()
plt.show()

# Free original memory
del X_mass
gc.collect()

# Step 2: Do the same for X_vel
print("Processing dark matter velocity...")
X_vel = np.load(r"/home/amanbh/projects/tf217/DISS/Maps_Vcdm_IllustrisTNG_LH_z=0.00.npy")
print(f"X_vel shape: {X_vel.shape}")
print(f"Dark Matter Velocity min-max: {X_vel.min()} - {X_vel.max()}")

X_vel = X_vel.astype(np.float32)
X_vel_norm = np.zeros_like(X_vel, dtype=np.float32)

for i in range(0, len(X_vel), batch_size):
    X_vel_norm[i:i+batch_size] = safe_log_normalize(X_vel[i:i+batch_size])

# Display one sample
plt.figure(figsize=(5, 5))
plt.imshow(X_vel_norm[0], cmap="coolwarm")
plt.title("Normalized Dark Matter Velocity")
plt.colorbar()
plt.show()

# Free memory
del X_vel
gc.collect()

# Step 3: Now stack the inputs
print("Stacking input arrays...")
X = np.stack([X_mass_norm, X_vel_norm], axis=-1)
print(f"Input shape: {X.shape}")

# Free memory
del X_mass_norm, X_vel_norm
gc.collect()

# Proceed with the same approach for outputs
print("Processing gas density...")
Y_gas = np.load(r"/home/amanbh/projects/tf217/DISS/Maps_Mgas_IllustrisTNG_LH_z=0.00.npy")
print(f"Y_gas shape: {Y_gas.shape}")
print(f"Gas Density min-max: {Y_gas.min()} - {Y_gas.max()}")

Y_gas = Y_gas.astype(np.float32)
Y_gas_norm = np.zeros_like(Y_gas, dtype=np.float32)

for i in range(0, len(Y_gas), batch_size):
    Y_gas_norm[i:i+batch_size] = safe_log_normalize(Y_gas[i:i+batch_size])

plt.figure(figsize=(5, 5))
plt.imshow(Y_gas_norm[0], cmap="viridis")
plt.title("Normalized Gas Density")
plt.colorbar()
plt.show()

# Free memory
del Y_gas
gc.collect()

print("Processing temperature...")
Y_temp = np.load(r"/home/amanbh/projects/tf217/DISS/Maps_T_IllustrisTNG_LH_z=0.00.npy")
print(f"Y_temp shape: {Y_temp.shape}")
print(f"Temperature min-max: {Y_temp.min()} - {Y_temp.max()}")

Y_temp = Y_temp.astype(np.float32)
Y_temp_norm = np.zeros_like(Y_temp, dtype=np.float32)

for i in range(0, len(Y_temp), batch_size):
    Y_temp_norm[i:i+batch_size] = safe_log_normalize(Y_temp[i:i+batch_size])

plt.figure(figsize=(5, 5))
plt.imshow(Y_temp_norm[0], cmap="plasma")
plt.title("Normalized Temperature")
plt.colorbar()
plt.show()

# Free memory
del Y_temp
gc.collect()

# Stack outputs
print("Stacking output arrays...")
Y = np.stack([Y_gas_norm, Y_temp_norm], axis=-1)
print(f"Output shape: {Y.shape}")

# Free memory
del Y_gas_norm, Y_temp_norm
gc.collect()

print("Data preparation complete!")
# Out:
# Processing dark matter mass...
# X_mass shape: (15000, 256, 256)
# Dark Matter Mass min-max: 2655544064.0 - 2499223484366848.0
# Processing dark matter velocity...
# X_vel shape: (15000, 256, 256)
# Dark Matter Velocity min-max: 4.384753227233887 - 1797.47607421875
# Stacking input arrays...
# Input shape: (15000, 256, 256, 2)
# Processing gas density...
# Y_gas shape: (15000, 256, 256)
# Gas Density min-max: 694237120.0 - 250120155168768.0
# Processing temperature...
# Y_temp shape: (15000, 256, 256)
# Temperature min-max: 1502.0494384765625 - 83233224.0
# Stacking output arrays...
# Output shape: (15000, 256, 256, 2)
# Data preparation complete!

# %%
import gc  # Garbage collection to free memory
import tensorflow as tf

# Free memory before training
gc.collect()
tf.keras.backend.clear_session()
# Out:
# 2025-03-10 21:24:34.138913: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 21:24:34.319511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741641874.381162    9531 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741641874.397360    9531 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-10 21:24:34.556606: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import train_test_split

# Split into train (70%), validation (15%), and test (15%)
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

print(f"Training samples: {X_train.shape[0]}")
print(f"Validation samples: {X_val.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
# Out:
# Training samples: 10500
# Validation samples: 2250
# Test samples: 2250

# %%
import gc  # Garbage collection to free memory
import tensorflow as tf

# Free memory before training
gc.collect()
tf.keras.backend.clear_session()

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2025-03-10 21:11:37.962077: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 21:11:38.147863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741641098.207920    7066 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741641098.223926    7066 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-10 21:11:38.379098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Num GPUs Available:  1

# %%
import tensorflow as tf

# Configure GPU
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print(f"Found {len(physical_devices)} GPUs: {physical_devices}")
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
    print("GPU memory growth enabled")
else:
    print("No GPU found, using CPU")
# Out:
# 2025-03-10 20:50:55.245592: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 20:50:55.451674: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741639855.528161     814 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741639855.548626     814 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-10 20:50:55.719767: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 1 GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU memory growth enabled

# %%
import tensorflow as tf

# ✅ Configure GPU to prevent TensorFlow from consuming all memory
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print(f"Found {len(physical_devices)} GPUs: {physical_devices}")
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
        tf.config.set_logical_device_configuration(
            device,
            [tf.config.LogicalDeviceConfiguration(memory_limit=10000)]  # ✅ Limit GPU usage to 10GB
        )
    print("GPU memory growth enabled & limited to 10GB")
else:
    print("No GPU found, using CPU instead.")

# ✅ Enable GPU device logging to confirm TensorFlow is actually using it
tf.debugging.set_log_device_placement(True)

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model

# ✅ Use a lightweight U-Net to reduce memory usage
def unet_model(input_shape):
    inputs = Input(input_shape)

    # Encoder (Lighter Model: 32 Filters instead of 64)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bottleneck (256 instead of 512 Filters)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)

    # Decoder
    up1 = UpSampling2D(size=(2, 2))(conv4)
    up1 = Conv2D(128, (3, 3), activation='relu', padding='same')(up1)
    merge1 = Concatenate()([up1, conv3])

    up2 = UpSampling2D(size=(2, 2))(merge1)
    up2 = Conv2D(64, (3, 3), activation='relu', padding='same')(up2)
    merge2 = Concatenate()([up2, conv2])

    up3 = UpSampling2D(size=(2, 2))(merge2)
    up3 = Conv2D(32, (3, 3), activation='relu', padding='same')(up3)
    merge3 = Concatenate()([up3, conv1])

    outputs = Conv2D(2, (1, 1), activation='sigmoid')(merge3)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# ✅ Initialize & Compile the Model
model = unet_model((256, 256, 2))  # Change input size as needed
model.summary()

# ✅ Train with a Smaller Batch Size to Reduce RAM Usage
model.fit(X, Y, batch_size=4, epochs=10, validation_split=0.1)  # 🔥 Batch Size = 4 to prevent memory issues
# Out:
# Found 1 GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU memory growth enabled & limited to 10GB
# input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# I0000 00:00:1741642325.186679    9531 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-03-10 21:32:05.453382: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:05.453416: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:05.453419: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.085851: I tensorflow/core/common_runtime/placer.cc:162] x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.085887: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.085891: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.318112: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.318157: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.318161: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.319829: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.319848: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.319852: I tensorflow/core/common_runtime/placer.cc:162] FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:06.319854: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:GPU:0
# key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# key: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# counter: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.108840: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.108884: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.108888: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.111851: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.111874: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.111877: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.114567: I tensorflow/core/common_runtime/placer.cc:162] seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.114587: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.114591: I tensorflow/core/common_runtime/placer.cc:162] key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.114593: I tensorflow/core/common_runtime/placer.cc:162] counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.122512: I tensorflow/core/common_runtime/placer.cc:162] shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.122534: I tensorflow/core/common_runtime/placer.cc:162] key: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.122537: I tensorflow/core/common_runtime/placer.cc:162] counter: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.122539: I tensorflow/core/common_runtime/placer.cc:162] alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.122542: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.122545: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.135866: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.135898: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.135903: I tensorflow/core/common_runtime/placer.cc:162] Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.135905: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.139138: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.139162: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.139166: I tensorflow/core/common_runtime/placer.cc:162] Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.139169: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.141524: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.141546: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.141552: I tensorflow/core/common_runtime/placer.cc:162] AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.141554: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.144160: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.144182: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.146850: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.146878: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.146893: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.150516: I tensorflow/core/common_runtime/placer.cc:162] dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.150542: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.150547: I tensorflow/core/common_runtime/placer.cc:162] Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.150549: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.154118: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.154148: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.155176: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.155196: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.155200: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.168610: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.168640: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.169709: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.169730: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.169735: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.172201: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.172229: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.183975: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.184008: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.185219: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.185246: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.185251: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.188147: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.188181: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.189474: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.189502: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.189507: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.199605: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.199637: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.200920: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.200946: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.200952: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.203993: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.204021: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.215578: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.215608: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.216691: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.216712: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.216718: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.219439: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.219471: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.220657: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.220683: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.220688: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.232083: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.232112: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.233322: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.233347: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.233352: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.235886: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.235917: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.248757: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.248792: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.249948: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.249973: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.249979: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.252584: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.252614: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.253692: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.253716: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.253721: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.264119: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.264150: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.265287: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.265312: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.265317: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.267853: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.267885: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.277181: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.277236: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.278510: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.278534: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.278540: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.281354: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.281385: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.292176: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.292210: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.293285: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.293307: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.293312: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.296028: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.296056: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.312972: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.313010: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.315617: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.315679: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.315694: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.319824: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.319883: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.333363: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.333396: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.334471: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.334494: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.334499: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.336899: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.336926: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.337907: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.337930: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.337934: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.345345: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.345375: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.346456: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.346480: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.346485: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.348652: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.348678: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.349662: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.349684: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.349689: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.353115: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.353143: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.356038: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-10 21:32:07.356061: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        608 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │    295,040 │ up_sampling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_8[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ concatenate[0][0] │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 128,  │    147,520 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_9[0][0],   │
# │ (Concatenate)       │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 256, 256,  │          0 │ concatenate_1[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │     36,896 │ up_sampling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_10[0][0],  │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 256, 256,  │        130 │ concatenate_2[0]… │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,651,554 (6.30 MB)
#  Trainable params: 1,651,554 (6.30 MB)
#  Non-trainable params: 0 (0.00 B)
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.382090: I tensorflow/core/common_runtime/placer.cc:162] start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.382117: I tensorflow/core/common_runtime/placer.cc:162] stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.382120: I tensorflow/core/common_runtime/placer.cc:162] step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.382125: I tensorflow/core/common_runtime/placer.cc:162] RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.382127: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.414471: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.414508: I tensorflow/core/common_runtime/placer.cc:162] MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.414511: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.419723: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.419747: I tensorflow/core/common_runtime/placer.cc:162] buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.419752: I tensorflow/core/common_runtime/placer.cc:162] PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.419755: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.430874: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.430908: I tensorflow/core/common_runtime/placer.cc:162] FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-10 21:32:07.430911: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model

# --- Define U-Net Model ---
def unet_model(input_shape):
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bottleneck
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)

    # Decoder
    up1 = UpSampling2D(size=(2, 2))(conv4)
    up1 = Conv2D(256, (3, 3), activation='relu', padding='same')(up1)
    merge1 = Concatenate()([up1, conv3])

    up2 = UpSampling2D(size=(2, 2))(merge1)
    up2 = Conv2D(128, (3, 3), activation='relu', padding='same')(up2)
    merge2 = Concatenate()([up2, conv2])

    up3 = UpSampling2D(size=(2, 2))(merge2)
    up3 = Conv2D(64, (3, 3), activation='relu', padding='same')(up3)
    merge3 = Concatenate()([up3, conv1])

    outputs = Conv2D(2, (1, 1), activation='sigmoid')(merge3)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Initialize and compile the model
model = unet_model(X.shape[1:])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │      1,216 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 128, 128,  │          0 │ conv2d_13[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv2d_15[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_4[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_16[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ conv2d_17[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_5[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_18[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 64, 64,    │          0 │ conv2d_19[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ up_sampling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_20[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_17[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │    589,952 │ up_sampling2d_4[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 128, 128,  │          0 │ conv2d_21[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 256, 256,  │          0 │ concatenate_4[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │    147,520 │ up_sampling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 256, 256,  │          0 │ conv2d_22[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 256, 256,  │        258 │ concatenate_5[0]… │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,602,434 (25.19 MB)
#  Trainable params: 6,602,434 (25.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, Y, batch_size=8, epochs=10, validation_split=0.1)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
