# %%
# Out:
# Resuming from epoch 51
# Previously processed 762640 samples
# Mapping datasets to memory...
# Total samples: 15000
# Resuming from sample 762640
# Loading model from training_checkpoints/recovered_model.keras
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      1,216 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
# Create model checkpoint callback
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, "model_epoch_{epoch:02d}.keras"),  # Add .keras extension
    save_best_only=False,
    save_weights_only=False,
    save_freq='epoch'
)

final_model_path = os.path.join(checkpoint_dir, "final_model.keras")

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import gc
import os
import json
from datetime import datetime

# Create a directory for checkpoints and tracking
checkpoint_dir = "training_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# Training state tracking file
training_state_file = os.path.join(checkpoint_dir, "training_state.json")

# Function to load or initialize training state
def load_or_init_training_state():
    if os.path.exists(training_state_file):
        with open(training_state_file, 'r') as f:
            return json.load(f)
    else:
        return {
            "epochs_completed": 0,
            "samples_seen": 0,
            "last_training_time": None,
            "model_checkpoint_path": None,
            "history": {
                "loss": [],
                "mae": []
            }
        }

# Load training state
training_state = load_or_init_training_state()
print(f"Resuming from epoch {training_state['epochs_completed']}")
print(f"Previously processed {training_state['samples_seen']} samples")

# ✅ Step 1: Use `np.memmap` to load `.npy` files without RAM overload
print("Mapping datasets to memory...")
X_mass = np.load("/home/amanbh/projects/tf217/DISS/Maps_Mcdm_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
X_vel  = np.load("/home/amanbh/projects/tf217/DISS/Maps_Vcdm_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
Y_gas  = np.load("/home/amanbh/projects/tf217/DISS/Maps_Mgas_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
Y_temp = np.load("/home/amanbh/projects/tf217/DISS/Maps_T_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')

total_samples = len(X_mass)
print(f"Total samples: {total_samples}")  # Check dataset size

# ✅ Step 2: Efficient Normalization (applied dynamically per batch)
def normalize_batch(batch, epsilon=1e-6):
    min_val = np.min(batch)
    max_val = np.max(batch)
    return np.log1p(batch - min_val + epsilon) / np.log1p(max_val - min_val + epsilon)

# ✅ Step 3: Create a Memory-Efficient Data Generator with resumption capability
def data_generator(start_idx=0, shuffle_indices=None):
    indices = np.arange(len(X_mass))
    
    # Shuffle if indices not provided
    if shuffle_indices is None:
        np.random.shuffle(indices)
        # Save shuffle state for resuming later
        shuffle_file = os.path.join(checkpoint_dir, "shuffle_indices.npy")
        np.save(shuffle_file, indices)
    else:
        indices = shuffle_indices
    
    # Start from where we left off
    for i in range(start_idx, len(indices)):
        idx = indices[i]
        X1 = normalize_batch(X_mass[idx])  # Dark matter mass
        X2 = normalize_batch(X_vel[idx])   # Dark matter velocity
        Y1 = normalize_batch(Y_gas[idx])   # Gas density
        Y2 = normalize_batch(Y_temp[idx])  # Temperature
        yield (np.stack([X1, X2], axis=-1), np.stack([Y1, Y2], axis=-1))

# Load shuffle indices if they exist
shuffle_file = os.path.join(checkpoint_dir, "shuffle_indices.npy")
if os.path.exists(shuffle_file) and training_state["samples_seen"] > 0:
    shuffle_indices = np.load(shuffle_file)
    # Calculate effective start index based on batches
    batch_size = 8  # Make sure this matches your batch size below
    start_sample = training_state["samples_seen"]
    print(f"Resuming from sample {start_sample}")
else:
    shuffle_indices = None
    start_sample = 0
    print("Starting fresh training run")

# ✅ Step 4: Convert Generator to TensorFlow Dataset with resumption
dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(start_sample, shuffle_indices), 
    output_signature=(
        tf.TensorSpec(shape=(256, 256, 2), dtype=tf.float32),
        tf.TensorSpec(shape=(256, 256, 2), dtype=tf.float32)
    )
)

# ✅ Step 5: Preprocess the Data Pipeline
batch_size = 8
dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# ✅ Step 6: Define U-Net Model (or any model you want)
def unet_model(input_shape):
    inputs = tf.keras.layers.Input(input_shape)

    # Encoder
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bottleneck
    conv4 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)

    # Decoder
    up1 = tf.keras.layers.UpSampling2D(size=(2, 2))(conv4)
    up1 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(up1)
    merge1 = tf.keras.layers.Concatenate()([up1, conv3])

    up2 = tf.keras.layers.UpSampling2D(size=(2, 2))(merge1)
    up2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(up2)
    merge2 = tf.keras.layers.Concatenate()([up2, conv2])

    up3 = tf.keras.layers.UpSampling2D(size=(2, 2))(merge2)
    up3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(up3)
    merge3 = tf.keras.layers.Concatenate()([up3, conv1])

    outputs = tf.keras.layers.Conv2D(2, (1, 1), activation='sigmoid')(merge3)

    model = tf.keras.models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Create a callback for tracking training state
class TrainingStateCallback(tf.keras.callbacks.Callback):
    def __init__(self, training_state, batch_size, save_every_n_batches=10):
        super(TrainingStateCallback, self).__init__()
        self.training_state = training_state
        self.batch_size = batch_size
        self.save_every_n_batches = save_every_n_batches
        self.batch_count = 0
        
    def on_train_begin(self, logs=None):
        self.training_state["last_training_time"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._save_state()
        
    def on_batch_end(self, batch, logs=None):
        self.batch_count += 1
        self.training_state["samples_seen"] += self.batch_size
        
        # Save state periodically
        if self.batch_count % self.save_every_n_batches == 0:
            self._save_state()
            
    def on_epoch_end(self, epoch, logs=None):
        # Update epoch counter and history
        self.training_state["epochs_completed"] += 1
        self.training_state["history"]["loss"].append(float(logs.get("loss")))
        self.training_state["history"]["mae"].append(float(logs.get("mae")))
        self._save_state()
    
    def _save_state(self):
        with open(training_state_file, 'w') as f:
            json.dump(self.training_state, f)

# Create a callback for live plotting with history
class LivePlotCallback(tf.keras.callbacks.Callback):
    def __init__(self, training_state, plot_interval=1):
        super(LivePlotCallback, self).__init__()
        self.plot_interval = plot_interval
        self.training_state = training_state
        
    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.plot_interval == 0:
            # Get history including previous runs
            loss_history = self.training_state["history"]["loss"] + [logs["loss"]]
            mae_history = self.training_state["history"]["mae"] + [logs["mae"]]
            epochs = list(range(len(loss_history)))
            
            # Create plot
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.plot(epochs, loss_history, 'b-', label='Loss (MSE)')
            plt.title('Loss vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.grid(True)
            
            plt.subplot(1, 2, 2)
            plt.plot(epochs, mae_history, 'r-', label='MAE')
            plt.title('MAE vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('MAE')
            plt.grid(True)
            
            plt.tight_layout()
            plt.savefig(os.path.join(checkpoint_dir, f"training_progress_epoch_{self.training_state['epochs_completed'] + epoch}.png"))
            plt.close()
            
            # Also display the plot
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.plot(epochs, loss_history, 'b-', label='Loss (MSE)')
            plt.title('Loss vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.grid(True)
            
            plt.subplot(1, 2, 2)
            plt.plot(epochs, mae_history, 'r-', label='MAE')
            plt.title('MAE vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('MAE')
            plt.grid(True)
            
            plt.tight_layout()
            plt.show()

# ✅ Step 7: Initialize or load model
model_checkpoint_path = training_state.get("model_checkpoint_path")
if model_checkpoint_path and os.path.exists(model_checkpoint_path):
    print(f"Loading model from {model_checkpoint_path}")
    model = tf.keras.models.load_model(model_checkpoint_path)
else:
    print("Creating new model")
    model = unet_model((256, 256, 2))  # Change input shape as needed

model.summary()

# Create model checkpoint callback
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, "model_epoch_{epoch:02d}.keras"),  # Add .keras extension
    save_best_only=False,
    save_weights_only=False,
    save_freq='epoch'
)

# Initialize training state callback
state_callback = TrainingStateCallback(training_state, batch_size)

# Initialize live plot callback
plot_callback = LivePlotCallback(training_state)

# Define how many more epochs to train
epochs_to_train = 50  # Change as needed

# 🚀 Train the model with tracking and checkpointing
history = model.fit(
    dataset, 
    epochs=epochs_to_train,
    callbacks=[checkpoint_callback, state_callback, plot_callback]
)

# Save final model
final_model_path = os.path.join(checkpoint_dir, "final_model")
model.save(final_model_path)
training_state["model_checkpoint_path"] = final_model_path
with open(training_state_file, 'w') as f:
    json.dump(training_state, f)

print(f"Training complete. Model saved to {final_model_path}")
print(f"Total epochs completed: {training_state['epochs_completed']}")
print(f"Total samples processed: {training_state['samples_seen']}")
# Out:
# Resuming from epoch 50
# Previously processed 750000 samples
# Mapping datasets to memory...
# Total samples: 15000
# Resuming from sample 750000
# Creating new model
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      1,216 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_24[0][0]   │
# ...

# %%
test_dataset = dataset.take(2)  # Take 2 batches from validation dataset for testing

# Get a small test batch
for test_batch in test_dataset:
    inputs, ground_truth = test_batch
    predictions = model.predict(inputs)
    
    # Calculate error metrics
    mae = tf.reduce_mean(tf.abs(ground_truth - predictions)).numpy()
    mse = tf.reduce_mean(tf.square(ground_truth - predictions)).numpy()
    print(f"Test MAE: {mae:.4f}, MSE: {mse:.4f}")
    
    # Visualize results
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    sample_idx = 1  # Choose first sample from batch
    
    # Input data
    im1 = axes[0,0].imshow(inputs[sample_idx,:,:,0])
    axes[0,0].set_title("Input: Dark Matter Density")
    plt.colorbar(im1, ax=axes[0,0], fraction=0.046, pad=0.04)
    
    im2 = axes[0,1].imshow(inputs[sample_idx,:,:,1])
    axes[0,1].set_title("Input: Dark Matter Velocity")
    plt.colorbar(im2, ax=axes[0,1], fraction=0.046, pad=0.04)
    
    # Ground truth
    im3 = axes[1,0].imshow(ground_truth[sample_idx,:,:,0])
    axes[1,0].set_title("Ground Truth: Gas Density")
    plt.colorbar(im3, ax=axes[1,0], fraction=0.046, pad=0.04)
    
    im4 = axes[1,1].imshow(ground_truth[sample_idx,:,:,1])
    axes[1,1].set_title("Ground Truth: Temperature")
    plt.colorbar(im4, ax=axes[1,1], fraction=0.046, pad=0.04)
    
    # Predictions
    im5 = axes[0,2].imshow(predictions[sample_idx,:,:,0])
    axes[0,2].set_title("Predicted: Gas Density")
    plt.colorbar(im5, ax=axes[0,2], fraction=0.046, pad=0.04)
    
    im6 = axes[1,2].imshow(predictions[sample_idx,:,:,1])
    axes[1,2].set_title("Predicted: Temperature")
    plt.colorbar(im6, ax=axes[1,2], fraction=0.046, pad=0.04)
    
    plt.tight_layout()
    plt.savefig('results_visualization.png')
    plt.show()
    
    # Only process the first batch to avoid too many plots
    break
# Out:
# 2025-03-11 15:36:46.307274: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.58GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 15:36:47.808304: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.40GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-11 15:36:48.449600: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.40GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# ...

# %%
# First, check what's in your training state
print("Current training state:", training_state)

# Update the epochs completed if needed (assuming you completed 50 epochs)
if training_state["epochs_completed"] == 0:  # If it wasn't updated
    training_state["epochs_completed"] = 50  # Set to the number of epochs you actually ran

# Make sure the history has some data, use the data from the history object if available
if hasattr(history, 'history') and 'loss' in history.history and len(training_state["history"]["loss"]) == 0:
    training_state["history"]["loss"] = [float(val) for val in history.history["loss"]]
    training_state["history"]["mae"] = [float(val) for val in history.history["mae"]]

# Save the model manually
emergency_model_path = os.path.join(checkpoint_dir, "recovered_model.keras")
model.save(emergency_model_path)
training_state["model_checkpoint_path"] = emergency_model_path

# Save the training state manually
with open(training_state_file, 'w') as f:
    json.dump(training_state, f)

# Save the shuffle indices if they exist
if shuffle_indices is not None:
    shuffle_file = os.path.join(checkpoint_dir, "shuffle_indices.npy")
    np.save(shuffle_file, shuffle_indices)

print(f"Emergency recovery complete. Model saved to: {emergency_model_path}")
print(f"Training state saved to: {training_state_file}")
# Out:
# Current training state: {'epochs_completed': 51, 'samples_seen': 750000, 'last_training_time': '2025-03-11 12:08:27', 'model_checkpoint_path': None, 'history': {'loss': [0.008519810624420643, 0.005292023532092571, 0.00479540042579174, 0.004633041098713875, 0.0044617243111133575, 0.004318412393331528, 0.0042107561603188515, 0.004148484207689762, 0.004077330697327852, 0.004060903564095497, 0.00403996417298913, 0.003996869549155235, 0.003995759878307581, 0.003949676174670458, 0.003927155863493681, 0.003917686175554991, 0.0038897106423974037, 0.003867482300847769, 0.0038435973692685366, 0.0038459866773337126, 0.003811164293438196, 0.003802032209932804, 0.003783830674365163, 0.003771236166357994, 0.003739669220522046, 0.003716174978762865, 0.0036785120610147715, 0.0036607258953154087, 0.0036344313994050026, 0.0035865847021341324, 0.003574698930606246, 0.003508863737806678, 0.003473276738077402, 0.0034225303679704666, 0.0033596395514905453, 0.003284882288426161, 0.003206019289791584, 0.003
# ...

# %%
# Load the saved model and training state
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import gc
import os
import json
from datetime import datetime

# Create a directory for checkpoints and tracking
checkpoint_dir = "training_checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# Training state tracking file
training_state_file = os.path.join(checkpoint_dir, "training_state.json")

# Load the training state
with open(training_state_file, 'r') as f:
    training_state = json.load(f)

print(f"Resuming from epoch {training_state['epochs_completed']}")
print(f"Previously processed {training_state['samples_seen']} samples")

# Load datasets with memory mapping
print("Mapping datasets to memory...")
X_mass = np.load("/home/amanbh/projects/tf217/DISS/Maps_Mcdm_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
X_vel  = np.load("/home/amanbh/projects/tf217/DISS/Maps_Vcdm_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
Y_gas  = np.load("/home/amanbh/projects/tf217/DISS/Maps_Mgas_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')
Y_temp = np.load("/home/amanbh/projects/tf217/DISS/Maps_T_IllustrisTNG_LH_z=0.00.npy", mmap_mode='r')

total_samples = len(X_mass)
print(f"Total samples: {total_samples}")

# Efficient Normalization function
def normalize_batch(batch, epsilon=1e-6):
    min_val = np.min(batch)
    max_val = np.max(batch)
    return np.log1p(batch - min_val + epsilon) / np.log1p(max_val - min_val + epsilon)

# Data generator with resumption capability
def data_generator(start_idx=0, shuffle_indices=None):
    indices = np.arange(len(X_mass))
    
    # Shuffle if indices not provided
    if shuffle_indices is None:
        np.random.shuffle(indices)
        # Save shuffle state for resuming later
        shuffle_file = os.path.join(checkpoint_dir, "shuffle_indices.npy")
        np.save(shuffle_file, indices)
    else:
        indices = shuffle_indices
    
    # Start from where we left off
    for i in range(start_idx, len(indices)):
        idx = indices[i]
        X1 = normalize_batch(X_mass[idx])  # Dark matter mass
        X2 = normalize_batch(X_vel[idx])   # Dark matter velocity
        Y1 = normalize_batch(Y_gas[idx])   # Gas density
        Y2 = normalize_batch(Y_temp[idx])  # Temperature
        yield (np.stack([X1, X2], axis=-1), np.stack([Y1, Y2], axis=-1))

# Load shuffle indices
shuffle_file = os.path.join(checkpoint_dir, "shuffle_indices.npy")
if os.path.exists(shuffle_file):
    shuffle_indices = np.load(shuffle_file)
    # Calculate start sample based on previous progress
    batch_size = 8
    start_sample = training_state["samples_seen"] % len(X_mass)  # Use modulo to handle wrapping
    print(f"Resuming from sample {start_sample}")
else:
    shuffle_indices = None
    start_sample = 0
    print("No shuffle indices found, starting fresh ordering")

# Create TensorFlow dataset
dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(start_sample, shuffle_indices), 
    output_signature=(
        tf.TensorSpec(shape=(256, 256, 2), dtype=tf.float32),
        tf.TensorSpec(shape=(256, 256, 2), dtype=tf.float32)
    )
)

# Preprocess data pipeline
batch_size = 8
dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Define U-Net model (only used if loading fails)
def unet_model(input_shape):
    inputs = tf.keras.layers.Input(input_shape)

    # Encoder
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)

    # Bottleneck
    conv4 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)

    # Decoder
    up1 = tf.keras.layers.UpSampling2D(size=(2, 2))(conv4)
    up1 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(up1)
    merge1 = tf.keras.layers.Concatenate()([up1, conv3])

    up2 = tf.keras.layers.UpSampling2D(size=(2, 2))(merge1)
    up2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(up2)
    merge2 = tf.keras.layers.Concatenate()([up2, conv2])

    up3 = tf.keras.layers.UpSampling2D(size=(2, 2))(merge2)
    up3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(up3)
    merge3 = tf.keras.layers.Concatenate()([up3, conv1])

    outputs = tf.keras.layers.Conv2D(2, (1, 1), activation='sigmoid')(merge3)

    model = tf.keras.models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Improved TrainingStateCallback with error handling
class TrainingStateCallback(tf.keras.callbacks.Callback):
    def __init__(self, training_state, batch_size, save_every_n_batches=10):
        super(TrainingStateCallback, self).__init__()
        self.training_state = training_state
        self.batch_size = batch_size
        self.save_every_n_batches = save_every_n_batches
        self.batch_count = 0
        
    def on_train_begin(self, logs=None):
        self.training_state["last_training_time"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self._save_state()
        
    def on_batch_end(self, batch, logs=None):
        self.batch_count += 1
        self.training_state["samples_seen"] += self.batch_size
        
        # Save state periodically
        if self.batch_count % self.save_every_n_batches == 0:
            self._save_state()
            
    def on_epoch_end(self, epoch, logs=None):
        # Update epoch counter and history with error handling
        self.training_state["epochs_completed"] += 1
        
        # Make sure logs is not None and has the expected keys
        if logs is not None:
            if "loss" in logs and logs["loss"] is not None:
                self.training_state["history"]["loss"].append(float(logs["loss"]))
            if "mae" in logs and logs["mae"] is not None:
                self.training_state["history"]["mae"].append(float(logs["mae"]))
        
        self._save_state()
    
    def _save_state(self):
        with open(training_state_file, 'w') as f:
            json.dump(self.training_state, f)

# Improved LivePlotCallback with error handling
class LivePlotCallback(tf.keras.callbacks.Callback):
    def __init__(self, training_state, plot_interval=1):
        super(LivePlotCallback, self).__init__()
        self.plot_interval = plot_interval
        self.training_state = training_state
        
    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.plot_interval == 0:
            # Get history including previous runs with error handling
            loss_history = self.training_state["history"]["loss"].copy()
            mae_history = self.training_state["history"]["mae"].copy()
            
            # Safely add current logs if available
            if logs is not None:
                if "loss" in logs and logs["loss"] is not None:
                    loss_history.append(logs["loss"])
                if "mae" in logs and logs["mae"] is not None:
                    mae_history.append(logs["mae"])
            
            if len(loss_history) == 0 or len(mae_history) == 0:
                print("Warning: No metrics data available for plotting")
                return
                
            epochs = list(range(len(loss_history)))
            
            # Create plot
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.plot(epochs, loss_history, 'b-', label='Loss (MSE)')
            plt.title('Loss vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.grid(True)
            
            plt.subplot(1, 2, 2)
            plt.plot(epochs, mae_history, 'r-', label='MAE')
            plt.title('MAE vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('MAE')
            plt.grid(True)
            
            plt.tight_layout()
            plt.savefig(os.path.join(checkpoint_dir, f"training_progress_epoch_{self.training_state['epochs_completed'] + epoch}.png"))
            plt.close()
            
            # Also display the plot
            plt.figure(figsize=(10, 5))
            plt.subplot(1, 2, 1)
            plt.plot(epochs, loss_history, 'b-', label='Loss (MSE)')
            plt.title('Loss vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('Loss')
            plt.grid(True)
            
            plt.subplot(1, 2, 2)
            plt.plot(epochs, mae_history, 'r-', label='MAE')
            plt.title('MAE vs Epochs')
            plt.xlabel('Epoch')
            plt.ylabel('MAE')
            plt.grid(True)
            
            plt.tight_layout()
            plt.show()

# Load the saved model with error handling
model_checkpoint_path = training_state.get("model_checkpoint_path")
if model_checkpoint_path and os.path.exists(model_checkpoint_path):
    try:
        print(f"Loading model from {model_checkpoint_path}")
        model = tf.keras.models.load_model(model_checkpoint_path)
    except Exception as e:
        print(f"Error loading model: {e}")
        print("Creating new model instead")
        model = unet_model((256, 256, 2))
else:
    print("No saved model found. Creating new model")
    model = unet_model((256, 256, 2))

model.summary()

# Create callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, "model_epoch_{epoch:02d}.keras"),
    save_best_only=False,
    save_weights_only=False,
    save_freq='epoch'
)

state_callback = TrainingStateCallback(training_state, batch_size)
plot_callback = LivePlotCallback(training_state)

# Define additional epochs to train
additional_epochs = 50  # Change this as needed

# Train the model with error handling
try:
    history = model.fit(
        dataset, 
        initial_epoch=training_state["epochs_completed"],  # Start from the last completed epoch
        epochs=training_state["epochs_completed"] + additional_epochs,  # Train for additional epochs
        callbacks=[checkpoint_callback, state_callback, plot_callback]
    )

    # Save final model
    final_model_path = os.path.join(checkpoint_dir, "final_model.keras")
    model.save(final_model_path)
    training_state["model_checkpoint_path"] = final_model_path
    with open(training_state_file, 'w') as f:
        json.dump(training_state, f)

    print(f"Training complete. Model saved to {final_model_path}")
    print(f"Total epochs completed: {training_state['epochs_completed']}")
    print(f"Total samples processed: {training_state['samples_seen']}")
    
except Exception as e:
    print(f"Error during training: {e}")
    # Save the current state and model before exiting
    checkpoint_path = os.path.join(checkpoint_dir, "emergency_save.keras")
    print(f"Attempting to save model to {checkpoint_path}")
    try:
        model.save(checkpoint_path)
        training_state["model_checkpoint_path"] = checkpoint_path
        with open(training_state_file, 'w') as f:
            json.dump(training_state, f)
        print("Emergency save successful")
    except Exception as save_error:
        print(f"Emergency save failed: {save_error}")
# Out:
# Resuming from epoch 51
# Previously processed 762640 samples
# Mapping datasets to memory...
# Total samples: 15000
# Resuming from sample 12640
# Loading model from training_checkpoints/recovered_model.keras
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      1,216 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
